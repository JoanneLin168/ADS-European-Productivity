# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
productivity = pd.read_csv("../Datasets/cleaned_Productivity.csv")
technology = pd.read_csv("../Datasets/TAI2000-2018_Overall.csv")
technology.head()
# Out:
#   Country_Name Country_Code      2000      2001      2002      2003      2004  \
# 0  Afghanistan          AFG  0.004489  0.006374  0.014635  0.023505  0.032512
# 1      Albania          ALB  0.218422  0.230951  0.242822  0.247619  0.257197
# 2      Algeria          DZA  0.166487  0.171746  0.177423  0.182908  0.196723
# 3       Angola          AGO  0.077702  0.097637  0.105566  0.110781  0.111409
# 4    Argentina          ARG  0.323863  0.344568  0.342679  0.348126  0.365217
#
#        2005      2006      2007  ...      2009      2010      2011      2012  \
# 0  0.044002  0.054365  0.065803  ...  0.089213  0.085963  0.093105  0.130045
# 1  0.269394  0.273600  0.291121  ...  0.317466  0.345352  0.366461  0.393062
# 2  0.219868  0.227779  0.244386  ...  0.245921  0.253603  0.261576  0.268053
# 3  0.115007  0.117140  0.130538  ...  0.131415  0.138366  0.149115  0.155742
# 4  0.377037  0.383146  0.394019  ...  0.406505  0.437918  0.454343  0.462491
#
# ...

# %%
# don't need the names and reformat
technology.drop(columns = "Country_Name", inplace=True)
technology.set_index("Country_Code", inplace=True)
technology
# Out:
#                   2000      2001      2002      2003      2004      2005  \
# Country_Code
# AFG           0.004489  0.006374  0.014635  0.023505  0.032512  0.044002
# ALB           0.218422  0.230951  0.242822  0.247619  0.257197  0.269394
# DZA           0.166487  0.171746  0.177423  0.182908  0.196723  0.219868
# AGO           0.077702  0.097637  0.105566  0.110781  0.111409  0.115007
# ARG           0.323863  0.344568  0.342679  0.348126  0.365217  0.377037
# ...                ...       ...       ...       ...       ...       ...
# VEN           0.265800  0.275979  0.280499  0.279019  0.293209  0.320398
# VNM           0.224077  0.245710  0.250799  0.257298  0.274236  0.292188
# YEM           0.078769  0.081217  0.087044  0.088376  0.086195  0.097170
# ZMB           0.092435  0.101177  0.098189  0.100658  0.103982  0.108035
# ZWE           0.132465  0.161274  0.163370  0.166902  0.167422  0.165669
#
#                   2006      2007      2008      2009      2010      2011  \
# ...

# %%
#extract only the countries in both
technology = technology[technology.index.isin(productivity["LOCATION"])]
