# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
productivity = '~/uniwork/ads/ADS-European-Productivity/Datasets/cleaned_Productivity.csv'
prod_df = pd.read_csv(productivity)
prod_df.drop(['2000', '2001','2002','2003','2004'], axis = 1, inplace =True)

# %%
prod_df.drop('mean', axis = 1, inplace = True)
prod_df
# Out:
#    LOCATION       2005        2006        2007       2008       2009  \
# 0       AUS  47.099677   47.342066   47.873036  49.523676  49.111719
# 1       AUT  60.632340   62.218785   63.814049  63.814456  63.363388
# 2       BEL  67.287921   67.637137   68.887444  68.464336  68.020751
# 3       BGR  17.965425   18.618248   19.229785  19.475667  19.717737
# 4       CAN  47.187987   47.742663   47.802103  47.658733  47.877704
# 5       CHE  64.693828   66.315161   67.595243  68.253612  66.723475
# 6       CHL  20.756781   21.576242   22.452244  22.983801  23.127019
# 7       COL  10.232035   10.890402   11.347122  11.360227  11.063533
# 8       CRI  13.718511   14.259665   14.453706  14.909054  15.331663
# 9       CZE  32.765277   34.781571   36.256014  36.139167  35.303035
# 10      DEU  59.900695   60.858653   61.577685  61.593702  59.739676
# 11      DNK  64.048343   64.892447   65.012119  64.044269  63.453957
# 12      ESP  45.562108   45.828539   46.335067  46.454358  47.573943
# ...

# %%
esi = "~/uniwork/ads/ADS-European-Productivity/Datasets/ESI_Clean.csv"
esi_df = pd.read_csv(esi)
esi_df.columns=esi_df.iloc[0]
esi_df.drop(0, inplace=True) 
geo = esi_df['Month-Year']
esi_df = esi_df.drop('Month-Year', axis = 1)
esi_df = esi_df.astype(np.float64)

esi_df['geo'] = geo
esi_df['2005'] = esi_df.filter(regex='-05').mean(axis=1)
esi_df['2006'] = esi_df.filter(regex='-06').mean(axis=1)
esi_df['2007'] = esi_df.filter(regex='-07').mean(axis=1)
esi_df['2008'] = esi_df.filter(regex='-08').mean(axis=1)
esi_df['2009'] = esi_df.filter(regex='-09').mean(axis=1)
esi_df['2010'] = esi_df.filter(regex='-10').mean(axis=1)
esi_df['2011'] = esi_df.filter(regex='-11').mean(axis=1)
esi_df['2012'] = esi_df.filter(regex='-12').mean(axis=1)
esi_df['2013'] = esi_df.filter(regex='-13').mean(axis=1)
esi_df['2014'] = esi_df.filter(regex='-14').mean(axis=1)
esi_df['2015'] = esi_df.filter(regex='-15').mean(axis=1)
esi_df['2016'] = esi_df.filter(regex='-16').mean(axis=1)
esi_df['2017'] = esi_df.filter(regex='-17').mean(axis=1)
esi_df['2018'] = esi_df.filter(regex='-18').mean(axis=1)
esi_df['2019'] = esi_df.filter(regex='-19').mean(axis=1)
esi_df['2020'] = esi_df.filter(regex='-20').mean(axis=1)
esi_df['2021'] = esi_df.filter(regex='-21').mean(axis=1)

esi_df = esi_df[['geo','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']]
esi_df.drop([1, 2],axis = 0, inplace=True)

# %%
for index, row in esi_df.iterrows():
    if row.geo == 'EL.ESI':
        row.geo = 'GR.ESI'
    if row.geo == 'UK.ESI':
        row.geo = 'GB.ESI'
    
    esi_df.at[index, 'geo'] = pycountry.countries.get(alpha_2 = row.geo[:-4]).alpha_3

# %%
esi_df
# Out:
# 0   geo        2005        2006        2007        2008       2009  \
# 3   BEL  100.966667  111.616667  112.150000   95.008333  80.416667
# 4   BGR  107.725000  111.033333  117.575000  114.716667  89.433333
# 5   CZE  108.166667  113.358333  114.400000  102.775000  80.383333
# 6   DNK  103.783333  113.016667  105.891667   88.466667  83.983333
# 7   DEU   93.783333  103.975000  105.808333   92.833333  82.025000
# 8   EST  111.216667  116.666667  108.391667   87.825000  75.525000
# 9   GRC  102.241667  108.100000  110.291667  101.166667  87.241667
# 10  ESP  104.841667  104.125000  103.350000   83.741667  79.866667
# 11  FRA  101.966667  107.641667  110.800000   93.575000  81.416667
# 12  CYP  101.708333  103.475000  109.350000  106.533333  91.458333
# 13  LVA  110.641667  113.833333  111.991667   91.191667  69.916667
# 14  LTU  108.166667  113.508333  114.341667   96.316667  69.858333
# 15  LUX  102.200000  105.325000  109.458333   93.483333  85.958333
# ...

# %%
#the full dataset doesn't load cause it's too big so this is just general government expenditure as percentage og gdp
gov_exp = '~/uniwork/ads/ADS-European-Productivity/Datasets/gov_exp.csv'
exp_df = pd.read_csv(gov_exp)

# %%
exp_df
# Out:
#                      DATAFLOW        LAST UPDATE freq    unit sector cofog99  \
# 0      ESTAT:GOV_10A_EXP(1.0)  22/02/23 11:00:00    A  PC_GDP    S13    GF01
# 1      ESTAT:GOV_10A_EXP(1.0)  22/02/23 11:00:00    A  PC_GDP    S13    GF01
# 2      ESTAT:GOV_10A_EXP(1.0)  22/02/23 11:00:00    A  PC_GDP    S13    GF01
# 3      ESTAT:GOV_10A_EXP(1.0)  22/02/23 11:00:00    A  PC_GDP    S13    GF01
# 4      ESTAT:GOV_10A_EXP(1.0)  22/02/23 11:00:00    A  PC_GDP    S13    GF01
# ...                       ...                ...  ...     ...    ...     ...
# 40795  ESTAT:GOV_10A_EXP(1.0)  22/02/23 11:00:00    A  PC_GDP    S13   TOTAL
# 40796  ESTAT:GOV_10A_EXP(1.0)  22/02/23 11:00:00    A  PC_GDP    S13   TOTAL
# 40797  ESTAT:GOV_10A_EXP(1.0)  22/02/23 11:00:00    A  PC_GDP    S13   TOTAL
# 40798  ESTAT:GOV_10A_EXP(1.0)  22/02/23 11:00:00    A  PC_GDP    S13   TOTAL
# 40799  ESTAT:GOV_10A_EXP(1.0)  22/02/23 11:00:00    A  PC_GDP    S13   TOTAL
#
# ...

# %%
#droping observation fact as there are not that many predited vales and it saves space
exp_df.drop('OBS_FLAG', axis = 1, inplace = True)

# %%
sectors = set(exp_df['cofog99'])
countries = set(exp_df['geo'])

# %%
#drop irrelevant columns
exp_df.drop('DATAFLOW', axis = 1, inplace = True)
exp_df.drop('LAST UPDATE', axis = 1, inplace = True)
exp_df.drop('unit', axis = 1, inplace = True)
exp_df.drop('sector', axis = 1, inplace = True)

# %%
exp_df.drop('freq', axis = 1, inplace = True)
exp_df.drop('na_item', axis = 1, inplace = True)
exp_df.head()
# Out:
#   cofog99 geo  TIME_PERIOD  OBS_VALUE
# 0    GF01  AT         2005        7.8
# 1    GF01  AT         2006        7.7
# 2    GF01  AT         2007        7.6
# 3    GF01  AT         2008        7.2
# 4    GF01  AT         2009        7.8

# %%
exp_df
# Out:
#       cofog99 geo  TIME_PERIOD  OBS_VALUE
# 0        GF01  AT         2005        7.8
# 1        GF01  AT         2006        7.7
# 2        GF01  AT         2007        7.6
# 3        GF01  AT         2008        7.2
# 4        GF01  AT         2009        7.8
# ...       ...  ..          ...        ...
# 40795   TOTAL  SK         2017       39.5
# 40796   TOTAL  SK         2018       39.7
# 40797   TOTAL  SK         2019       40.5
# 40798   TOTAL  SK         2020       44.8
# 40799   TOTAL  SK         2021       46.3
#
# [40800 rows x 4 columns]

# %%
exp_df = exp_df[exp_df['cofog99'] != 'TOTAL']
exp_df
# Out:
#       cofog99 geo  TIME_PERIOD  OBS_VALUE
# 0        GF01  AT         2005        7.8
# 1        GF01  AT         2006        7.7
# 2        GF01  AT         2007        7.6
# 3        GF01  AT         2008        7.2
# 4        GF01  AT         2009        7.8
# ...       ...  ..          ...        ...
# 40285  GF1009  SK         2017        1.4
# 40286  GF1009  SK         2018        1.3
# 40287  GF1009  SK         2019        1.2
# 40288  GF1009  SK         2020        1.3
# 40289  GF1009  SK         2021        1.2
#
# [40290 rows x 4 columns]

# %%
#atempting to get 80 different colours
from matplotlib.colors import hsv_to_rgb

hue_values = np.linspace(0, 1, 80)
ones = np.ones_like(hue_values)
# Convert the hue values to RGB colors using the hsv_to_rgb function

colors = hsv_to_rgb(np.column_stack([hue_values, ones, ones]))

# %%
# plot values o for each country
# for country in countries:
#     print(country)
#     fig = plt.figure(figsize=(12, 10))
#     to_plot_df = exp_df[exp_df['geo'] == country]
#     for i, (cofog99, group_df) in enumerate(to_plot_df.groupby('cofog99')):
#         plt.plot(group_df['TIME_PERIOD'], group_df['OBS_VALUE'], color=colors[i], label=cofog99)

#     plt.xlabel('Time Period')
#     plt.ylabel('OBS_VALUE')
#     plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
german_prod = prod_df.iloc[10].values[1:]
german_esi = es_df.iloc[7].values[1:]
german_expenditure = exp_df.loc[exp_df['geo'] == 'DE', 'OBS_VALUE'].values
german_expenditure = np.split(german_expenditure, 79)

# %%
import pycountry

# %%
#prepare government expenditure dataset so it has teh same country codes as productivity
exp_df_prod = exp_df.copy()
for country in countries:
    
    if country == 'EL':
        exp_df_prod.replace(country, 'GRC', inplace =True)
    else: exp_df_prod.replace(country, pycountry.countries.get(alpha_2=country).alpha_3, inplace =True)

# %%
countries = set(exp_df_prod.geo)
countries
# exp_df_prod[exp_df_prod['geo'] =='SVN']
# Out:
# {'AUT',
#  'BEL',
#  'BGR',
#  'CHE',
#  'CYP',
#  'CZE',
#  'DEU',
#  'DNK',
#  'ESP',
#  'EST',
#  'FIN',
#  'FRA',
#  'GRC',
#  'HRV',
#  'HUN',
#  'IRL',
#  'ISL',
#  'ITA',
#  'LTU',
#  'LUX',
#  'LVA',
#  'MLT',
#  'NLD',
#  'NOR',
#  'POL',
#  'PRT',
#  'ROU',
#  'SVK',
#  'SVN',
#  'SWE'}

# %%
exp_df_prod
# Out:
#       cofog99  geo  TIME_PERIOD  OBS_VALUE
# 0        GF01  AUT         2005        7.8
# 1        GF01  AUT         2006        7.7
# 2        GF01  AUT         2007        7.6
# 3        GF01  AUT         2008        7.2
# 4        GF01  AUT         2009        7.8
# ...       ...  ...          ...        ...
# 40285  GF1009  SVK         2017        1.4
# 40286  GF1009  SVK         2018        1.3
# 40287  GF1009  SVK         2019        1.2
# 40288  GF1009  SVK         2020        1.3
# 40289  GF1009  SVK         2021        1.2
#
# [40290 rows x 4 columns]

# %%
#get rid of teh countries in expenditure but not in productivity
for country in countries:
    if country not in set(prod_df.LOCATION) or country not in set(esi_df.geo):
        exp_df_prod = exp_df_prod[exp_df_prod.geo != country]

# %%
#get rid of countries in productivity but not in expenditure
countries = set(prod_df.LOCATION)
for country in countries:
    if country not in set(exp_df_prod.geo) or country not in set(esi_df.geo):
        prod_df = prod_df[prod_df.LOCATION != country]

# %%
countries = set(esi_df.geo)
for country in countries:
    if country not in set(prod_df.LOCATION) or country not in set(exp_df_prod.geo):
        esi_df = esi_df[esi_df.geo != country]

# %%
countries = set(prod_df.LOCATION)

prod_timeseries = pd.melt(prod_df, id_vars = ['LOCATION'], var_name = 'YEAR', value_name= 'PRODUCTIVITY').sort_values('LOCATION')
prod_timeseries
# Out:
#     LOCATION  YEAR  PRODUCTIVITY
# 0        AUT  2005     60.632340
# 198      AUT  2014     66.327394
# 154      AUT  2012     65.645538
# 220      AUT  2015     67.267651
# 132      AUT  2011     64.947960
# ..       ...   ...           ...
# 65       SWE  2007     65.489276
# 307      SWE  2018     69.514519
# 43       SWE  2006     65.301313
# 241      SWE  2015     69.074511
# 373      SWE  2021     73.669232
#
# [374 rows x 3 columns]

# %%
esi_timeseries = pd.melt(esi_df, id_vars = ['geo'], var_name = 'YEAR', value_name= 'ESI').sort_values('geo')

# %%
cofog99 = set(exp_df_prod.cofog99)
cofog99
# Out:
# {'GF01',
#  'GF0101',
#  'GF0102',
#  'GF0103',
#  'GF0104',
#  'GF0105',
#  'GF0106',
#  'GF0107',
#  'GF0108',
#  'GF02',
#  'GF0201',
#  'GF0202',
#  'GF0203',
#  'GF0204',
#  'GF0205',
#  'GF03',
#  'GF0301',
#  'GF0302',
#  'GF0303',
#  'GF0304',
#  'GF0305',
#  'GF0306',
#  'GF04',
#  'GF0401',
#  'GF0402',
#  'GF0403',
#  'GF0404',
#  'GF0405',
#  'GF0406',
#  'GF0407',
#  'GF0408',
#  'GF0409',
#  'GF05',
#  'GF0501',
#  'GF0502',
#  'GF0503',
#  'GF0504',
#  'GF0505',
#  'GF0506',
#  'GF06',
#  'GF0601',
#  'GF0602',
#  'GF0603',
#  'GF0604',
#  'GF0605',
#  'GF0606',
#  'GF07',
#  'GF0701',
#  'GF0702',
#  'GF0703',
#  'GF0704',
#  'GF0705',
#  'GF0706',
#  'GF08',
#  'GF0801',
#  'GF0802',
#  'GF0803',
#  'GF0804',
#  'GF0805',
#  'GF0806',
#  'GF09',
#  'GF0901',
#  'GF0902',
#  'GF0903',
#  'GF0904',
#  'GF0905',
#  'GF0906',
#  'GF0907',
#  'GF0908',
#  'GF10',
#  'GF1001',
#  'GF1002',
#  'GF1003',
#  'GF1004',
#  'GF1005',
#  'GF1006',
#  'GF1007',
#  'GF1008',
# ...

# %%
esi_timeseries.head
# Out:
# <bound method NDFrame.head of      geo  YEAR         ESI
# 366  AUT  2021  111.916667
# 124  AUT  2010  100.575000
# 278  AUT  2017  112.033333
# 14   AUT  2005   97.791667
# 168  AUT  2012   94.650000
# ..   ...   ...         ...
# 65   SWE  2007  109.666667
# 153  SWE  2011  102.816667
# 43   SWE  2006  107.858333
# 131  SWE  2010  108.300000
# 373  SWE  2021  115.025000
#
# [374 rows x 3 columns]>

# %%
prod_timeseries.head
# Out:
# <bound method NDFrame.head of     LOCATION  YEAR  PRODUCTIVITY
# 0        AUT  2005     60.632340
# 198      AUT  2014     66.327394
# 154      AUT  2012     65.645538
# 220      AUT  2015     67.267651
# 132      AUT  2011     64.947960
# ..       ...   ...           ...
# 65       SWE  2007     65.489276
# 307      SWE  2018     69.514519
# 43       SWE  2006     65.301313
# 241      SWE  2015     69.074511
# 373      SWE  2021     73.669232
#
# [374 rows x 3 columns]>

# %%
exp_df_prod.head
# Out:
# <bound method NDFrame.head of       cofog99  geo  TIME_PERIOD  OBS_VALUE
# 0        GF01  AUT         2005        7.8
# 1        GF01  AUT         2006        7.7
# 2        GF01  AUT         2007        7.6
# 3        GF01  AUT         2008        7.2
# 4        GF01  AUT         2009        7.8
# ...       ...  ...          ...        ...
# 40285  GF1009  SVK         2017        1.4
# 40286  GF1009  SVK         2018        1.3
# 40287  GF1009  SVK         2019        1.2
# 40288  GF1009  SVK         2020        1.3
# 40289  GF1009  SVK         2021        1.2
#
# [29546 rows x 4 columns]>

# %%
for i in cofog99:
    data = exp_df_prod[exp_df_prod.cofog99 == i]
    data['prod'] = np.asarray(prod_timeseries.PRODUCTIVITY).astype(np.float64)
    data['esi'] = np.asarray(esi_timeseries.ESI).astype(np.float64)
    print(i)
    print("Correlation with productivity:")
    print(data[['prod', 'OBS_VALUE']].corr())
    print("Correlation with ESI:")
    print(data[['esi', 'OBS_VALUE']].corr())
# Out:
# /tmp/ipykernel_89625/2179130700.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['prod'] = np.asarray(prod_timeseries.PRODUCTIVITY).astype(np.float64)
# /tmp/ipykernel_89625/2179130700.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['esi'] = np.asarray(esi_timeseries.ESI).astype(np.float64)
# /tmp/ipykernel_89625/2179130700.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#correlation between government expenditure and productivity in germany
german_prod = german_prod.astype('float64')
j = 0
for i in german_expenditure:
    # print(i.dtype)
    print(list(sectors)[j])
    j+=1
    print(np.corrcoef(i, german_prod))
# Out:
# GF08
# [[ 1.         -0.65784641]
#  [-0.65784641  1.        ]]
# GF0505
# [[1.         0.81059526]
#  [0.81059526 1.        ]]
# GF0803
# [[1.         0.90814876]
#  [0.90814876 1.        ]]
# GF10
# [[1.        0.8580432]
#  [0.8580432 1.       ]]
# GF0106
# [[1.         0.80265179]
#  [0.80265179 1.        ]]
# GF0907
# [[nan nan]
#  [nan  1.]]
# GF0205
# [[1.         0.36991713]
#  [0.36991713 1.        ]]
# GF0104
# [[ 1.         -0.97424613]
#  [-0.97424613  1.        ]]
# GF0302
# [[nan nan]
#  [nan  1.]]
# GF1008
# [[1.         0.59021609]
#  [0.59021609 1.        ]]
# GF0402
# [[1.         0.49595211]
#  [0.49595211 1.        ]]
# GF0506
# [[nan nan]
#  [nan  1.]]
# GF1007
# [[1.         0.72513942]
#  [0.72513942 1.        ]]
# GF0107
# [[nan nan]
#  [nan  1.]]
# GF0502
# [[nan nan]
#  [nan  1.]]
# GF0605
# [[1.         0.50415944]
#  [0.50415944 1.        ]]
# GF0802
# [[1.         0.39979028]
#  [0.39979028 1.        ]]
# GF0403
# [[1.         0.75697087]
# ...

# %%
#correlation between esi and general government expenditure in germany
german_esi = german_esi.astype('float64')
j = 0
for i in german_expenditure:
    # print(i.dtype)
    print(list(sectors)[j])
    j+=1
    print(np.corrcoef(i, german_esi))
# Out:
# GF08
# [[ 1.         -0.25684333]
#  [-0.25684333  1.        ]]
# GF0505
# [[ 1.         -0.05015437]
#  [-0.05015437  1.        ]]
# GF0803
# [[ 1.        -0.0060638]
#  [-0.0060638  1.       ]]
# GF10
# [[ 1.         -0.06650896]
#  [-0.06650896  1.        ]]
# GF0106
# [[ 1.         -0.11328192]
#  [-0.11328192  1.        ]]
# GF0907
# [[nan nan]
#  [nan  1.]]
# GF0205
# [[ 1.         -0.06600237]
#  [-0.06600237  1.        ]]
# GF0104
# [[ 1.         -0.06815167]
#  [-0.06815167  1.        ]]
# GF0302
# [[nan nan]
#  [nan  1.]]
# GF1008
# [[1.         0.27357299]
#  [0.27357299 1.        ]]
# GF0402
# [[1.         0.26041691]
#  [0.26041691 1.        ]]
# GF0506
# [[nan nan]
#  [nan  1.]]
# GF1007
# [[1.         0.09721454]
#  [0.09721454 1.        ]]
# GF0107
# [[nan nan]
#  [nan  1.]]
# GF0502
# [[nan nan]
#  [nan  1.]]
# GF0605
# [[1.         0.18463417]
#  [0.18463417 1.        ]]
# GF0802
# [[1.         0.15770107]
#  [0.15770107 1.        ]]
# GF0403
# ...
